# %%
import networkx as nx
import pandas as pd
from collections import defaultdict

G = nx.read_graphml('graphs/reddit/merged_all_events_louvain.graphml')

comms = defaultdict(set)
for i, attr in G.nodes(data=True):
    comm = attr["community"]
    comms[comm].add(i)

comms_list = {
    10: None,
    0: None,
    7: None,
    1: None
}
def classify_strong_sentiment(score):
    if score >= 0.6:
        return 'strong_positive'
    elif score <= -0.6:
        return 'strong_negative'
    else:
        return 'other'
    
df = pd.read_csv('datasets/reddit_with_sentiment.csv')

df['lda_text'] = df['clean_text']
df['strong_sentiment'] = df['vader_score'].apply(classify_strong_sentiment)

for i in comms_list:
    comms_list[i] = df[df["author"].isin(comms[i])].copy()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation


# LDA topic function
def get_topics_from_texts(texts, n_topics=8, n_top_words=10):
    # Drop NaN or empty strings before vectorization
    texts = texts.dropna()
    texts = texts[texts.str.strip() != '']
    
    vectorizer = CountVectorizer(max_df=0.95, min_df=5, stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(X)

    words = vectorizer.get_feature_names_out()
    topic_keywords = []
    for topic_idx, topic in enumerate(lda.components_):
        top_words = [words[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        topic_keywords.append((f"Topic {topic_idx + 1}", top_words))
    return topic_keywords

    
for comm in comms_list:
    for sentiment in ['strong_positive', 'strong_negative']:
        subset = comms_list[comm]
        subset = subset[subset["strong_sentiment"] == sentiment]
        if not subset.empty:
            print(f"\n({len(subset)}) Top Topics in {sentiment.replace('_', ' ').title()} Comments - {comm}")
            topics = get_topics_from_texts(subset['lda_text'])
            for topic, keywords in topics:
                print(f"{topic}: {', '.join(keywords)}")
# Out:
# (2333) Top Topics in Strong Positive Comments - 10
# Topic 1: game, people, dont, love, like, thanks, world, olympics, better, wow
# Topic 2: like, lol, medal, look, win, gold, athlete, thats, super, great
# Topic 3: theme, series, final, fantasy, heart, hero, star, trigger, kingdom, chrono
# Topic 4: sport, olympics, year, great, time, week, really, game, ive, watching
# Topic 5: love, best, great, good, song, lmao, ceremony, time, athlete, thing
# Topic 6: awesome, amazing, game, ceremony, olympics, think, happy, time, guy, like
# Topic 7: ceremony, olympic, closing, medal, opening, fencing, love, bach, champion, thomas
# Topic 8: olympics, like, paris, really, french, great, beautiful, world, france, people
#
# (546) Top Topics in Strong Negative Comments - 10
# Topic 1: dont, time, olympics, know, medal, watch, game, world, didnt, event
# Topic 2: fuck, shit, damn, olympics, year, miss, covid, nbc, need, world
# Topic 3: hell, fucking, year, fucked, fuck, wtf, yeah, way, theyre, country
# Topic 4: olympics, american, hell, worst, feel, going, say, end, want, like
# Topic 5: people, time, minute, life, live, long, understand, dont, killed, worry
# Topic 6: ceremony, opening, closing, thing, speech, game, like, imagine, worst, japanese
# Topic 7: bad, really, sad, hate, getting, olympics, feel, people, thats, game
# Topic 8: ad, nbc, commercial, ceremony, olympic, killing, cut, missing, athlete, game
#
# (1379) Top Topics in Strong Positive Comments - 0
# Topic 1: world, cup, group, saudi, country, winner, arabia, poland, argentina, mexico
# Topic 2: like, football, lol, cup, great, match, world, people, team, thats
# Topic 3: spain, win, game, germany, like, great, japan, team, player, match
# Topic 4: like, group, think, player, best, far, france, game, dont, england
# Topic 5: best, final, team, messi, match, time, play, win, group, amazing
# Topic 6: game, good, like, fan, year, team, player, going, lmao, played
# Topic 7: team, game, like, win, good, england, france, argentina, play, better
# Topic 8: team, win, play, game, cup, think, ball, world, ecuador, best
#
# (538) Top Topics in Strong Negative Comments - 0
# Topic 1: hell, team, tournament, football, day, match, people, fucking, lose, england
# Topic 2: cup, world, worst, team, game, qatar, host, ive, feel, shit
# Topic 3: game, team, thats, maybe, year, dont, right, england, lack, argentina
# Topic 4: penalty, time, goal, player, ive, dead, seen, say, ref, dont
# Topic 5: qatar, shit, fuck, bad, fucking, rigged, way, people, look, country
# Topic 6: game, fifa, stadium, think, really, man, bad, fucked, war, missed
# Topic 7: offside, need, wasnt, good, mad, gonna, young, english, argentina, getting
# Topic 8: damn, going, like, penalty, miss, final, spain, german, match, wtf
#
# (957) Top Topics in Strong Positive Comments - 7
# Topic 1: lol, like, look, home, medal, country, let, team, save, didnt
# Topic 2: game, goal, time, team, england, like, great, croatia, final, win
# Topic 3: world, cup, win, germany, playing, better, team, spain, croatia, game
# Topic 4: good, best, people, happy, like, guy, seen, year, football, life
# Topic 5: team, best, play, like, player, spain, game, russia, right, chance
# Topic 6: good, game, pretty, win, match, sure, dont, hope, want, russia
# Topic 7: lmao, like, great, tournament, game, yeah, people, nice, better, team
# Topic 8: love, croatia, fan, spain, like, croatian, think, possession, great, russia
#
# (486) Top Topics in Strong Negative Comments - 7
# Topic 1: ball, poor, time, minute, like, guy, good, feel, watch, pas
# Topic 2: spain, dont, team, player, attack, come, curse, hate, believe, time
# Topic 3: worst, thats, penalty, time, neymar, wtf, pissed, player, hell, seen
# Topic 4: team, like, shit, dont, play, people, qatar, brazil, germany, think
# Topic 5: shit, really, bad, going, spain, russia, ref, say, money, isnt
# Topic 6: world, cup, goal, edit, win, penalty, war, lose, russia, getting
# Topic 7: fuck, kill, shit, gonna, putin, die, penalty, game, want, boring
# Topic 8: fucking, game, pique, fucked, hurt, penalty, time, got, subasic, pressure
#
# (726) Top Topics in Strong Positive Comments - 1
# Topic 1: win, like, argentina, team, good, final, best, player, football, guy
# Topic 2: world, happy, love, cup, croatia, team, game, messi, congratulation, didnt
# Topic 3: world, cup, best, team, time, final, win, football, match, game
# Topic 4: team, player, best, time, world, win, game, croatia, thought, know
# Topic 5: game, think, goal, england, france, really, people, play, better, chance
# Topic 6: like, good, right, penalty, man, chance, lmao, league, save, look
# Topic 7: team, played, love, dont, need, play, winner, thing, look, good
# Topic 8: great, team, like, france, morocco, canada, year, final, messi, better
#
# (259) Top Topics in Strong Negative Comments - 1
# Topic 1: time, team, way, game, world, final, cup, lot, player, place
# Topic 2: worst, argentina, team, world, bad, cup, year, qatar, final, game
# Topic 3: fucked, world, going, performance, end, got, cup, dude, dont, god
# Topic 4: penalty, england, ive, seen, worst, didnt, brazil, southgate, game, france
# Topic 5: match, fuck, group, long, level, game, time, tournament, half, chance
# Topic 6: penalty, kane, really, french, like, good, right, ref, missed, think
# Topic 7: shit, world, holy, fuck, qatar, cup, today, croatia, like, sad
# Topic 8: fifa, hell, people, world, game, good, cup, minute, tournament, player

# %%
from collections import Counter

words = """
Topic 1: time, team, way, game, world, final, cup, lot, player, place
Topic 2: worst, argentina, team, world, bad, cup, year, qatar, final, game
Topic 3: fucked, world, going, performance, end, got, cup, dude, dont, god
Topic 4: penalty, england, ive, seen, worst, didnt, brazil, southgate, game, france
Topic 5: match, fuck, group, long, level, game, time, tournament, half, chance
Topic 6: penalty, kane, really, french, like, good, right, ref, missed, think
Topic 7: shit, world, holy, fuck, qatar, cup, today, croatia, like, sad
Topic 8: fifa, hell, people, world, game, good, cup, minute, tournament, player
"""

for i in range(8):
    words = words.replace(f"Topic {i+1}:", "")

words = [i.strip() for i in words.split(",")]

result = dict(Counter(words).most_common())
print(", ".join([i for i in result if result[i] > 1]))
# Out:
# world, cup, game, time, team, final, player, qatar, fuck, tournament, like, good
